# %%
from tika import parser
import pandas as pd
import numpy as np
import string
import time
import re
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer

# %%
def my_analyzer(s):
    # Synonym List
    """syns = {'veh': 'vehicle', 'car': 'vehicle', 'chev':'cheverolet', \
              'chevy':'cheverolet', 'air bag': 'airbag', \
              'seat belt':'seatbelt', "n't":'not', 'to30':'to 30', \
              'wont':'would not', 'cant':'can not', 'cannot':'can not', \
              'couldnt':'could not', 'shouldnt':'should not', \
              'wouldnt':'would not', 'straightforward': 'straight forward' }
    """
    
    # Preprocess String s
    s = s.lower()
    # Replace special characters with spaces
    s = s.replace('-', ' ')
    s = s.replace('_', ' ')
    s = s.replace(',', '. ')
    # Replace not contraction with not
    s = s.replace("'nt", " not")
    s = s.replace("n't", " not")
    # Tokenize 
    tokens = word_tokenize(s)
    #tokens = [word.replace(',','') for word in tokens ]
    tokens = [word for word in tokens if ('*' not in word) and \
              ("''" != word) and ("``" != word) and \
              (word!='description') and (word !='dtype') \
              and (word != 'object') and (word!="'s")]
    
    # Map synonyms
    """for i in range(len(tokens)):
        if tokens[i] in syns:
            tokens[i] = syns[tokens[i]]
    """
            
    # Remove stop words
    punctuation = list(string.punctuation)+['..', '...']
    pronouns = ['i', 'he', 'she', 'it', 'him', 'they', 'we', 'us', 'them']
    others   = ["'d", "co", "ed", "put", "say", "get", "can", "become",\
                "los", "sta", "la", "use", "iii", "else","honda","vehicle"\
                "dealer","problem"]
    stop = stopwords.words('english') + punctuation + pronouns + others
    filtered_terms = [word for word in tokens if (word not in stop) and \
                  (len(word)>1) and (not word.replace('.','',1).isnumeric()) \
                  and (not word.replace("'",'',2).isnumeric())]
    
    # Lemmatization & Stemming - Stemming with WordNet POS
    # Since lemmatization requires POS need to set POS
    tagged_words = pos_tag(filtered_terms, lang='eng')
    # Stemming with for terms without WordNet POS
    stemmer = SnowballStemmer("english")
    wn_tags = {'N':wn.NOUN, 'J':wn.ADJ, 'V':wn.VERB, 'R':wn.ADV}
    wnl = WordNetLemmatizer()
    stemmed_tokens = []
    for tagged_token in tagged_words:
        term = tagged_token[0]
        pos  = tagged_token[1]
        pos  = pos[0]
        try:
            pos   = wn_tags[pos]
            stemmed_tokens.append(wnl.lemmatize(term, pos=pos))
        except:
            stemmed_tokens.append(stemmer.stem(term))
    return stemmed_tokens

TEST = corpus = [
     'This is the first document.'
]

#TEST = my_analyzer
tfidf_vect = TfidfVectorizer(max_df=1.0,
                             min_df=1, 
                             max_features=None,
                             lowercase=True)

raw = parser.from_file("D:/BOOKS/Ross_Probability10ed_Student_Solutions2010.pdf")

def new_analyzer(s):
    s = s.lower()
    return re.findall(r'[a-z]+', s)
#res = tfidf_vect.fit(list(raw['content']))
#tfidf_vect.get_feature_names()
print(new_analyzer(raw['content']))
# Out:
# ['instructor', 'manual', 'accompany', 'introduction', 'probability', 'model', 'tenth', 'edition', 'sheldon', 'm.', 'ross', 'university', 'southern', 'california', 'angeles', 'ca', 'amsterdam', 'boston', 'heidelberg', 'london', 'new', 'york', 'oxford', 'paris', 'san', 'diego', 'san', 'francisco', 'singapore', 'sydney', 'tokyo', 'academic', 'press', 'imprint', 'elsevier', 'academic', 'press', 'imprint', 'elsevier', 'corporate', 'drive', 'suite', 'burlington', 'usa', 'street', 'suite', 'san', 'diego', 'california', 'usa', 'elsevier', 'boulevard', 'langford', 'lane', 'kidlington', 'oxford', 'ox5', '1gb', 'uk', 'copyright', 'c©', 'elsevier', 'inc.', 'right', 'reserve', 'part', 'publication', 'may', 'reproduce', 'transmitted', 'form', 'mean', 'electronic', 'mechanical', 'include', 'photocopy', 'record', 'information', 'storage', 'retrieval', 'system', 'without', 'permission', 'write', 'publisher', 'detail', 'seek', 'permission', 'information', 'publisher', 'permission', 'policy', 'arrangement', 'organization', 'copyright', 'clearance', 'center', 'copyright', 'license', 'agency', 'find', 'website', 'www.elsevier.com/permissions', 'book', 'individual', 'contribution', 'contain', 'protected', 'copyright', 'publisher', 'may', 'note', 'herein', 'notice', 'knowledge', 'best', 'practice', 'field', 'constantly', 'change', 'new', 'research', 'experience', 'broaden', 'understanding', 'change', 'research', 'method', 'professional', 'practice', 'medical', 'treatment', 'may', 'necessary', 'practitioner', 'researcher', 'must', 'always', 'rely', 'experience', 'knowledge', 'evaluate', 'use', 'information', 'method', 'compound', 'experiment', 'describe', 'herein', 'use', 'information', 'method', 'mindful', 'safety', 'safety', 'others', 'include', 'party', 'professional', 'responsibility', 'full', 'extent', 'law', 'neither', 'publisher', 'author', 'contributor', 'editor', 'assume', 'liability', 'injury', 'and/or', 'damage', 'person', 'property', 'matter', 'product', 'liability', 'negligence', 'otherwise', 'operation', 'method', 'product', 'instruction', 'idea', 'contain', 'material', 'herein', 'isbn', 'information', 'academic', 'press', 'publication', 'visit', 'web', 'site', 'www.elsevierdirect.com', 'typeset', 'diacritech', 'india', 'content', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'r.', 'r.', 'r.', 'g.', 'g.', 'g.', 'b.', 'b.', 'b.', 'probability', 'point', '1/9', 'r.', 'r.', 'g.', 'g.', 'b.', 'b.', 'e1', 'e2', 'en', 'ei', 'head', 'tail', 'addition', 'en', 'en−1', 'head', 'ei', 'head', 'ei+1', 'tails', 'toss', 't.', 't.', 'h.', 'h.', 't.', 'h.', 'fecgc', 'efgc', 'ef', 'eg', 'fg', 'efg', 'ecfcgc', 'ef', 'eg', 'fg', 'efg', 'win', 'win', 'lose', 'lose', 'occur', 'occur', 'either', 'occur', 'therefore', 'either', 'ef', 'eg', 'occur', 'ef', 'eg', 'similarly', 'ef', 'eg', 'occur', 'either', 'ef', 'eg', 'occur', 'thus', 'occur', 'either', 'occur', 'occurs', 'hence', 'ef', 'eg', 'together', 'reverse', 'inequality', 'prove', 'result', 'occur', 'occur', 'occur', 'ec', 'occur', 'fc', 'thus', 'ec', 'fc', 'occur', 'hence', 'ecfc', 'ecfc', 'occur', 'ec', 'occurs', 'fc', 'occur', 'hence', 'neither', 'occurs', 'thus', 'thus', 'ecfc', 'result', 'follow', 'ef', 'fec', 'implying', 'sinc', 'fec', 'disjoint', 'fe', 'c.', 'either', 'induction', 'n∪', 'ei', 'e1', 'ec1e2', 'ec1ec2e3', 'ec1', 'ecn−1en', 'term', 'right', 'side', 'mutually', 'exclusive', 'ei', 'e1', 'ec1e2', 'ec1ec2e3', 'ec1', 'ecn−1en', 'e1', 'e2', 'en', 'sum', '⎧⎪⎪⎨', '⎪⎪⎩', 'either', 'hint', 'condition', 'initial', 'outcome', 'initial', 'outcome', 'initial', 'outcome', 'initial', 'outcome', 'neither', 'answer', 'solution', 'therefore', 'condition', 'initial', 'toss', 'win', 'i=2', 'win', 'throw', 'throw', 'win|', 'throw', '⎧⎪⎪⎪⎪⎪⎪⎪⎪⎨', '⎪⎪⎪⎪⎪⎪⎪⎪⎩', 'obtain', 'use', 'problem', 'win', 'win', 'n=0', 'win', '2n', 'st', 'toss', 'n=0', '2np', 'n=0', '2p', 'p2', 'win', 'win', 'fec', 'fec', 'sinc', 'fec', 'disjoint', 'als ...

# %%
def new_analyzer(s):
    s = s.lower()
    tokens = re.findall(r'[a-z]+', s)
    # Remove stop words
    punctuation = list(string.punctuation)+['..', '...']
    pronouns = ['i', 'he', 'she', 'it', 'him', 'they', 'we', 'us', 'them']
    others   = ["'d", "co", "ed", "put", "say", "get", "can", "become",\
                "los", "sta", "la", "use", "iii", "else","honda","vehicle"\
                "dealer","problem"]
    stop = stopwords.words('english') + punctuation + pronouns + others
    tokens = [token for token in tokens if (token not in stop) and (len(token) > 5)]
    return tokens
print(new_analyzer(raw['content']))
# Out:
# ['instructor', 'manual', 'accompany', 'introduction', 'probability', 'models', 'edition', 'sheldon', 'university', 'southern', 'california', 'angeles', 'amsterdam', 'boston', 'heidelberg', 'london', 'oxford', 'francisco', 'singapore', 'sydney', 'academic', 'imprint', 'elsevier', 'academic', 'imprint', 'elsevier', 'corporate', 'burlington', 'street', 'california', 'elsevier', 'boulevard', 'langford', 'kidlington', 'oxford', 'copyright', 'elsevier', 'rights', 'reserved', 'publication', 'reproduced', 'transmitted', 'electronic', 'mechanical', 'including', 'photocopying', 'recording', 'information', 'storage', 'retrieval', 'system', 'without', 'permission', 'writing', 'publisher', 'details', 'permission', 'information', 'publisher', 'permissions', 'policies', 'arrangements', 'organizations', 'copyright', 'clearance', 'center', 'copyright', 'licensing', 'agency', 'website', 'elsevier', 'permissions', 'individual', 'contributions', 'contained', 'protected', 'copyright', 'publisher', 'herein', 'notices', 'knowledge', 'practice', 'constantly', 'changing', 'research', 'experience', 'broaden', 'understanding', 'changes', 'research', 'methods', 'professional', 'practices', 'medical', 'treatment', 'necessary', 'practitioners', 'researchers', 'always', 'experience', 'knowledge', 'evaluating', 'information', 'methods', 'compounds', 'experiments', 'described', 'herein', 'information', 'methods', 'mindful', 'safety', 'safety', 'others', 'including', 'parties', 'professional', 'responsibility', 'fullest', 'extent', 'neither', 'publisher', 'authors', 'contributors', 'editors', 'assume', 'liability', 'injury', 'damage', 'persons', 'property', 'matter', 'products', 'liability', 'negligence', 'otherwise', 'operation', 'methods', 'products', 'instructions', 'contained', 'material', 'herein', 'information', 'academic', 'publications', 'elsevierdirect', 'typeset', 'diacritech', 'contents', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'chapter', 'probability', 'addition', 'tosses', 'ecfcgc', 'occurs', 'occurs', 'either', 'therefore', 'either', 'occurs', 'similarly', 'occurs', 'either', 'occurs', 'occurs', 'either', 'occurs', 'occurs', 'together', 'reverse', 'inequality', 'proves', 'result', 'occurs', 'occurs', 'occurs', 'occurs', 'neither', 'occurs', 'result', 'follows', 'implying', 'disjoint', 'either', 'induction', 'mutually', 'exclusive', 'either', 'condition', 'initial', 'outcome', 'initial', 'outcome', 'initial', 'outcome', 'initial', 'outcome', 'neither', 'answers', 'solutions', 'therefore', 'condition', 'initial', 'obtained', 'problems', 'disjoint', 'disjointness', 'continue', 'biased', 'oldest', 'number', 'number', 'sample', 'different', 'number', 'exactly', 'numbers', 'numbers', 'different', 'events', 'mutually', 'exclusive', 'define', 'sample', 'possible', 'values', 'second', 'number', 'answers', 'solutions', 'person', 'female', 'female', 'consist', 'points', 'points', 'probability', 'player', 'points', 'played', 'trials', 'result', 'player', 'winning', 'points', 'results', 'players', 'winning', 'points', 'independence', 'obtain', 'points', 'needed', 'probability', 'signify', 'always', 'reasoning', 'second', 'denomination', 'different', 'different', 'different', 'different', 'spades', 'answers', 'solutions', 'equivalent', 'equivalent', 'george', 'exactly', 'george', 'exactly', 'person', 'selects', 'selects', 'number', 'specific', 'select', 'number', 'arranged', 'number', 'summation', 'number', 'choose', 'variables', 'selects', 'student', 'sophomore', 'student', 'freshman', 'student', 'student', 'number', 'sophomore', 'number', 'students', 'system', 'successive', 'independent', 'pattern', 'appear', 'marble', 'chosen', 'marble', 'answers', 'solutions', 'transfer', 'resigns', 'events', 'person', 'resigning', 'respec', 'tively', 'flipped', 'headed', 'flipped', 'parents', 'sibling', 'parents', 'hybrids', 'either', 'offspring', 'offspring', 'equally', 'likely', 'either', ' ...

# %%
tfidf_vect = TfidfVectorizer(max_df=1,
                             min_df=0, 
                             max_features=None,
                             lowercase=False)
con_vect = CountVectorizer()
tfidf_vect.fit(new_analyzer(raw['content']))
con_vect.fit(new_analyzer(raw['content']))
print(len(tfidf_vect.get_feature_names()))
tfidf_vect.get_feature_names()
con_vect.vocabulary_
tfidf_vect.vocabulary_
# Out:
# 676
# {'instructor': 329,
#  'manual': 369,
#  'accompany': 4,
#  'introduction': 333,
#  'models': 386,
#  'edition': 214,
#  'sheldon': 568,
#  'university': 649,
#  'southern': 580,
#  'angeles': 27,
#  'amsterdam': 25,
#  'boston': 58,
#  'heidelberg': 296,
#  'london': 362,
#  'francisco': 271,
#  'singapore': 574,
#  'sydney': 616,
#  'corporate': 147,
#  'burlington': 63,
#  'street': 598,
#  'boulevard': 59,
#  'langford': 347,
#  'kidlington': 342,
#  'rights': 554,
#  'reserved': 540,
#  'publication': 503,
#  'reproduced': 534,
#  'transmitted': 635,
#  'electronic': 216,
#  'mechanical': 377,
#  'photocopying': 467,
#  'recording': 517,
#  'storage': 595,
#  'retrieval': 550,
#  'details': 186,
#  'policies': 476,
#  'arrangements': 41,
#  'organizations': 434,
#  'clearance': 91,
#  'center': 79,
#  'licensing': 359,
#  'agency': 16,
#  'website': 666,
#  'contributions': 141,
#  'protected': 500,
#  'notices': 413,
#  'practice': 482,
#  'constantly': 131,
#  'broaden': 62,
#  'understanding': 645,
#  'medical': 378,
#  'treatment': 636,
#  'necessary': 402,
#  'practitioners': 483,
#  'researchers': 538,
#  'evaluating': 244,
#  'compounds': 120,
#  'experiments': 253,
#  'described': 182,
#  'mindful': 381,
#  'others': 437,
#  'responsibility': 544,
#  'fullest': 274,
#  'extent': 256,
#  'authors': 45,
#  'contributors': 142,
#  'editors': 215,
#  'damage': 165,
#  'persons': 464,
#  'negligence': 403,
#  'instructions': 328,
#  'material': 372,
#  'publications': 504,
#  'elsevierdirect': 217,
#  'typeset': 638,
#  'diacritech': 190,
#  'contents': 137,
#  'tosses': 630,
#  'ecfcgc': 213,
#  'problems': 498,
#  'disjointness': 197,
#  'continue': 139,
#  'oldest': 422,
#  'signify': 571,
#  'denomination': 174,
#  'spades': 581,
#  'specific': 582,
#  'arranged': 39,
#  'summation': 609,
#  'freshman': 273,
#  'students': 601,
#  'appear': 33,
#  'transfer': 632,
#  'resigns': 542,
#  'resigning': 541,
#  'respec': 543,
#  'tively': 628,
#  'headed': 294,
#  'sibling': 570,
#  'hybrids': 300,
#  'reasonable': 512,
#  'invalid': 334,
#  'condemned': 127,
#  'objects': 415,
#  'losses': 364,
#  'differentiation': 192,
#  'coupons': 151,
#  'geomet': 279,
#  'earliest': 212,
#  'collisions': 96,
#  'collision': 95,
#  'making': 368,
#  'construct': 134,
#  'hospital': 297,
#  'aikajtcov': 19,
#  'aikajk': 18,
#  'matching': 371,
#  'depending': 180,
#  'bilistically': 54,
#  'formally': 265,
#  'pendence': 460,
#  'numerator': 414,
#  'freedom': 272,
#  'recursively': 519,
#  'stands': 587,
#  'subtracting': 606,
#  'playing': 474,
#  'putting': 505,
#  'cycles': 164,
#  'restarts': 545,
#  'minutes': 384,
#  'examples': 245,
#  'computationally': 123,
#  'reselected': 539,
#  'tomorrow': 629,
#  'excluding': 249,
#  'compete': 117,
#  'nonred': 410,
#  'poissons': 475,
#  'lowing': 366,
#  'pairings': 440,
#  'scheduled': 560,
#  'erwise': 238,
#  'remain': 525,
#  'discrete': 196,
#  'computing': 124,
#  'received': 515,
#  'obtains': 418,
#  'removal': 527,
#  'pictures': 469,
#  'ackack': 7,
#  'considering': 129,
#  'request': 535,
#  'optimal': 427,
#  'optimum': 429,
#  'proved': 501,
#  'fixing': 260,
#  'hypothe': 301,
#  'constraint': 133,
#  'lowest': 365,
#  'nonnegative': 408,
#  'require': 536,
#  'picked': 468,
#  'surement': 613,
#  'developed': 189,
#  'children': 86,
#  'raining': 510,
#  'cubing': 161,
#  'selections': 561,
#  'current': 162,
#  'makeup': 367,
#  'reached': 511,
#  'subpath': 602,
#  'exists': 250,
#  'strictly': 599,
#  'returning': 551,
#  'contradicts': 140,
#  'stochas': 593,
#  'modulo': 387,
#  'multiplying': 399,
#  'sition': 575,
#  'barefooted': 52,
#  'percent': 461,
#  'employee': 225,
#  'employees': 226,
#  'categories': 76,
#  'cloudy': 92,
#  'switches': 614,
#  'performance': 462,
#  'counter': 148,
#  'followed': 263,
#  'accessible': 2,
#  'periods': 463,
#  'communicates': 112,
#  'impossible': 308,
#  'originating': 435,
#  'transi': 634,
#  'sitions': 576,
#  'typical': 639,
#  'converge': 143,
#  'umbrellas': 641,
#  'verified': 659,
#  'policyholder': 477,
#  'yearly': 674,
#  'counterclockwise': 149,
#  'rewritten': 553,
#  'inverse': 335,
#  'metric': 380,
#  'perusing': 465,
#  'subset': 603,
#  'pijpjk': 470,
#  'pjkpkj': 472,
#  'rjpjipjk': 556,
#  'rjpjkpji': 557,
#  'straightforward': 596,
#  'processors': 499,
#  'utilize': 657,
#  'positions': 480,
#  'knight': 343,
#  'weights': 667,
#  'yiapij': 675,
#  'discounted': 194,
#  'employed': 224,
#  'underlying': 644,
#  'finished': 259,
#  'rigorous': 555,
#  'replace': 532,
#  'throughout': 623,
#  'quently': 507,
#  'cessor': 82,
#  'connect': 128,
#  'joined': 340,
#  'amounts': 24,
#  'blocking': 57,
#  'entrance': 235,
#  'ditioned': 200,
#  'animal': 28,
#  'appointment': 35,
#  'doctor': 202,
#  'office': 420,
#  'justify': 341,
#  'imating': 306,
#  'possess': 481,
#  'denoting': 176,
#  'accident': 3,
#  'fortune': 269,
#  'themomentthat': 619,
#  'thenth': 620,
#  'headoccurs': 295,
#  'whenindepen': 668,
#  'coming': 109,
#  'classified': 88,
#  'approximate': 37,
#  'estimated': 242,
#  'formulas': 268,
#  'variances': 658,
#  'passing': 447,
#  'statement': 589,
#  'expect': 252,
#  'lawyers': 352,
#  'unreported': 650,
#  'claims': 87,
#  'launched': 350,
#  'accord': 5,
#  'occurring': 419,
#  'depart': 178,
#  'provided': 502,
#  'uncounted': 643,
#  'namely': 401,
#  'elsewhere': 218,
#  'statistics': 590,
#  'instances': 326,
#  'arbitrary': 38,
#  'laping': 348,
#  'lapping': 349,
#  'nonoverlapping': 409,
#  'increment': 321,
#  'cannot': 73,
#  'multiple': 398,
#  'nonhomogeneous': 407,
#  'ordinary': 433,
#  'affects': 15,
#  'withdrawal': 671,
#  'coeffi': 94,
#  'represents': 533,
#  'recognize': 516,
#  'matings': 375,
#  'mating': 374,
#  'analyze': 26,
#  'contact': 135,
#  'involve': 336,
#  'uninfected': 648,
#  'employ': 223,
#  'substitute': 605,
#  'nonempty': 406,
#  'deaths': 167,
#  'kolmogorov': 344,
#  'population': 479,
#  'cesses': 81,
#  'business': 64,
#  'improve': 309,
#  'attendant': 44,
#  'vicing': 662,
#  'repair': 529,
#  'repairmen': 530,
#  'observe': 416,
#  'future': 275,
#  'deleted': 173,
#  'denotes': 175,
#  'iterating': 338,
#  'exponentially': 255,
#  'suggests': 607,
#  'fourth': 270,
#  'requiring': 537,
#  'cation': 77,
#  'supposes': 611,
#  'phones': 466,
#  'truncation': 637,
#  'includes': 317,
#  'except': 248,
#  'uniformized': 647,
#  'version': 661,
#  'integrating': 330,
#  'markovian': 370,
#  'pikpkj': 471,
#  'assert': 43,
#  'probabilistically': 497,
#  'interested': 331,
#  'terminology': 618,
#  'established': 241,
#  'imation': 307,
#  'uniformization': 646,
#  'exceeding': 246,
#  'identi': 302,
#  'certain': 80,
#  'months': 396,
#  'calculated': 67,
#  'reneval': 528,
#  'completely': 118,
#  'stopped': 594,
#  'observing': 417,
#  'incorrect': 319,
#  'applicable': 34,
#  'switching': 615,
#  'places': 473,
#  'lengths': 356,
#  'dispatched': 198,
#  'resulting': 548,
#  'discov': 195,
#  'increase': 320,
#  'totals': 631,
#  'beginning': 53,
#  'cleaning': 90,
#  'cleaned': 89,
#  'launching': 351,
#  'viewing': 663,
#  'orbiting': 430,
#  'orbits': 431,
#  'delayed': 172,
#  'skiing': 577,
#  'supposing': 612,
#  'animation': 29,
#  'distance': 199,
#  'driver': 208,
#  'driving': 209,
#  'receive': 514,
#  'ticket': 626,
#  'official': 421,
#  'earlier': 211,
#  'theory': 621,
#  'writes': 673,
#  'letter': 357,
#  'supposed': 610,
#  'tijpijpi': 627,
#  'tially': 624,
#  'unaffected': 642,
#  'actual': 8,
#  'inspection': 325,
#  'paradox': 441,
#  'departing': 179,
#  'questioned': 508,
#  'consti': 132,
#  'visiting': 664,
#  'questioning': 509,
#  'longer': 363,
#  'staying': 591,
#  'hotels': 298,
#  'imately': 305,
#  'consistent': 130,
#  'repeating': 531,
#  'saying': 559,
#  'datavaluesaredistinct': 166,
#  'lettingrdenote': 358,
#  'therewardearnedbetweenrenewalepochs': 622,
#  'modeled': 385,
#  'stream': 597,
#  'restate': 546,
#  'employer': 227,
#  'willing': 669,
#  'boundary': 60,
#  'stable': 586,
#  'explanation': 254,
#  'faster': 257,
#  'stability': 585,
#  'comparison': 115,
#  'mathematically': 373,
#  'capacity': 75,
#  'available': 50,
#  'handed': 292,
#  'shelves': 569,
#  'introduce': 332,
#  'indicate': 323,
#  'checker': 84,
#  'completes': 119,
#  'systemrate': 617,
#  'regular': 522,
#  'resumes': 549,
#  'particular': 446,
#  'essence': 239,
#  'cutting': 163,
#  'getting': 282,
#  'verifies': 660,
#  'sampler': 558,
#  'network': 404,
#  'enables': 228,
#  'disciplines': 193,
#  'identical': 303,
#  'finding': 258,
#  'cancel': 71,
#  'notice': 412,
#  'exneyn': 251,
#  'cancels': 72,
#  'little': 360,
#  'reveals': 552,
#  'notational': 411,
#  'priority': 496,
#  'compared': 114,
#  'averaging': 51,
#  'compare': 113,
#  'serving': 564,
#  'minimizes': 382,
#  'concerned': 126,
#  'combining': 108,
#  'regarding': 521,
#  'calculate': 66,
#  'something': 579,
#  'happens': 293,
#  'calculating': 68,
#  'commences': 110,
#  'checks': 85,
#  'alteracting': 22,
#  'erlang': 236,
#  'essential': 240,
#  'simply': 572,
#  'solves': 578,
#  'minixi': 383,
#  'contain': 136,
#  'irrelevant': 337,
#  'ponent': 478,
#  'structure': 600,
#  'agrees': 17,
#  'overlap': 438,
#  'derive': 181,
#  'bounds': 61,
#  'densities': 177,
#  'related': 524,
#  'arrangement': 40,
#  'parallel': 442,
#  'recall': 513,
#  'decrease': 168,
#  'entiate': 234,
#  'counterexample': 150,
#  'concave': 125,
#  'remark': 526,
#  'mutations': 400,
#  'evaluated': 243,
#  'reduces': 520,
#  'recovering': 518,
#  'divide': 201,
#  'selling': 562,
#  'winnings': 670,
#  'defining': 171,
#  'squares': 583,
#  'formal': 264,
#  'continuation': 138,
#  'appropriate': 36,
#  'former': 267,
#  'preferable': 484,
#  'accepted': 1,
#  'iterations': 339,
#  'rejection': 523,
#  'differen': 191,
#  'tiating': 625,
#  'stirling': 592,
#  'acceptance': 0,
#  'exceeds': 247,
#  'resultant': 547,
#  'sequentially': 563,
#  'ordered': 432,
#  'inductive': 324,
#  'quantities': 506,
#  'encodepages': 232,
#  'allowtransparency': 21,
#  'autopositionepsfiles': 48,
#  'autorotatepages': 49,
#  'binding': 55,
#  'calgrayprofile': 69,
#  'calrgbprofile': 70,
#  'calcmykprofile': 65,
#  'coated': 93,
#  'srgbprofile': 584,
#  'cannotembedfontpolicy': 74,
#  'compatibilitylevel': 116,
#  'compressobjects': 121,
#  'compresspages': 122,
#  'convertimagestoindexed': 145,
#  'passthroughjpegimages': 448,
#  'createjdffile': 154,
#  'createjobticket': 155,
#  'defaultrenderingintent': 170,
#  'default': 169,
#  'detectblends': 187,
#  'detectcurves': 188,
#  'colorconversionstrategy': 97,
#  'leavecolorunchanged': 353,
#  'dothumbnails': 203,
#  'embedallfonts': 219,
#  'embedopentype': 221,
#  'parseiccprofilesincomments': 445,
#  'embedjoboptions': 220,
#  'dscreportinglevel': 210,
#  'emitdscwarnings': 222,
#  'endpage': 233,
#  'imagememory': 304,
#  'lockdistillerparams': 361,
#  'maxsubsetpct': 376,
#  'optimize': 428,
#  'parsedsccomments': 443,
#  'parsedsccommentsfordocinfo': 444,
#  'preservecopypage': 486,
#  'preservedicmykvalues': 487,
#  'preserveepsinfo': 489,
#  'preserveflatness': 490,
#  'preservehalftoneinfo': 491,
#  'preserveopicomments': 492,
#  'preserveoverprintsettings': 493,
#  'startpage': 588,
#  'subsetfonts': 604,
#  'transferfunctioninfo': 633,
#  'ucrandbginfo': 640,
#  'preserve': 485,
#  'useprologue': 656,
#  'colorsettingsfile': 107,
#  'alwaysembed': 23,
#  'neverembed': 405,
#  'antialiascolorimages': 30,
#  'cropcolorimages': 157,
#  'colorimageminresolution': 104,
#  'colorimageminresolutionpolicy': 105,
#  'downsamplecolorimages': 205,
#  'colorimagedownsampletype': 101,
#  'colorimageresolution': 106,
#  'colorimagedepth': 99,
#  'colorimagemindownsampledepth': 103,
#  'colorimagedownsamplethreshold': 100,
#  'encodecolorimages': 229,
#  'colorimagefilter': 102,
#  'autofiltercolorimages': 46,
#  'colorimageautofilterstrategy': 98,
#  'antialiasgrayimages': 31,
#  'cropgrayimages': 158,
#  'grayimageminresolution': 289,
#  'grayimageminresolutionpolicy': 290,
#  'downsamplegrayimages': 206,
#  'grayimagedownsampletype': 286,
#  'grayimageresolution': 291,
#  'grayimagedepth': 284,
#  'grayimagemindownsampledepth': 288,
#  'grayimagedownsamplethreshold': 285,
#  'encodegrayimages': 230,
#  'grayimagefilter': 287,
#  'autofiltergrayimages': 47,
#  'grayimageautofilterstrategy': 283,
#  'antialiasmonoimages': 32,
#  'cropmonoimages': 160,
#  'monoimageminresolution': 393,
#  'monoimageminresolutionpolicy': 394,
#  'downsamplemonoimages': 207,
#  'monoimagedownsampletype': 391,
#  'monoimageresolution': 395,
#  'monoimagedepth': 388,
#  'monoimagedownsamplethreshold': 390,
#  'encodemonoimages': 231,
#  'monoimagefilter': 392,
#  'ccittfaxencode': 78,
#  'monoimagedict': 389,
#  'allowpsxobjects': 20,
#  'checkcompliance': 83,
#  'acheck': 6,
#  'pdfxcompliantpdfonly': 450,
#  'pdfxnotrimboxerror': 451,
#  'pdfxtrimboxtomediaboxoffset': 459,
#  'pdfxsetbleedboxtomediabox': 457,
#  'pdfxbleedboxtotrimboxoffset': 449,
#  'pdfxoutputintentprofile': 454,
#  'pdfxoutputconditionidentifier': 453,
#  'pdfxoutputcondition': 452,
#  'pdfxregistryname': 456,
#  'pdfxtrapped': 458,
#  'description': 183,
#  'gebruik': 276,
#  'instellingen': 327,
#  'geoptimaliseerd': 281,
#  'afdrukken': 14,
#  'kwaliteit': 346,
#  'gemaakte': 277,
#  'kunnen': 345,
#  'worden': 672,
#  'geopend': 280,
#  'settings': 567,
#  'create': 152,
#  'suited': 608,
#  'printing': 495,
#  'created': 153,
#  'opened': 426,
#  'common': 111,
#  'othernamespaces': 436,
#  'asreaderspreads': 42,
#  'cropimagestoframes': 159,
#  'errorcontrol': 237,
#  'warnandcontinue': 665,
#  'flattenerignorespreadoverrides': 261,
#  'includeguidesgrids': 311,
#  'includenonprinting': 315,
#  'includeslug': 318,
#  'indesign': 322,
#  'omitplacedbitmaps': 423,
#  'omitplacedeps': 424,
#  'omitplacedpdf': 425,
#  'simulateoverprint': 573,
#  'legacy': 355,
#  'addbleedmarks': 9,
#  'addcolorbars': 10,
#  'addcropmarks': 11,
#  'addpageinfo': 12,
#  'addregmarks': 13,
#  'convertcolors': 144,
#  'converttocmyk': 146,
#  'destinationprofilename': 184,
#  'destinationprofileselector': 185,
#  'downsample': 204,
#  'bitimages': 56,
#  'flattenerpreset': 262,
#  'presetselector': 494,
#  'mediumresolution': 379,
#  'formelements': 266,
#  'generatestructure': 278,
#  'includebookmarks': 310,
#  'includehyperlinks': 312,
#  'includeinteractive': 313,
#  'includelayers': 314,
#  'includeprofiles': 316,
#  'multimediahandling': 397,
#  'useobjectsettings': 655,
#  'creativesuite': 156,
#  'pdfxoutputintentprofileselector': 455,
#  'preserveediting': 488,
#  'untaggedcmykhandling': 651,
#  'leaveuntagged': 354,
#  'untaggedrgbhandling': 652,
#  'usedocumentprofile': 654,
#  'usedocumentbleed': 653,
#  'setdistillerparams': 565,
#  'hwresolution': 299,
#  'pagesize': 439,
#  'setpagedevice': 566}

# %%
set(tfidf_vect.vocabulary_.keys())
# Out:
# {'acceptance',
#  'accepted',
#  'accessible',
#  'accident',
#  'accompany',
#  'accord',
#  'acheck',
#  'ackack',
#  'actual',
#  'addbleedmarks',
#  'addcolorbars',
#  'addcropmarks',
#  'addpageinfo',
#  'addregmarks',
#  'afdrukken',
#  'affects',
#  'agency',
#  'agrees',
#  'aikajk',
#  'aikajtcov',
#  'allowpsxobjects',
#  'allowtransparency',
#  'alteracting',
#  'alwaysembed',
#  'amounts',
#  'amsterdam',
#  'analyze',
#  'angeles',
#  'animal',
#  'animation',
#  'antialiascolorimages',
#  'antialiasgrayimages',
#  'antialiasmonoimages',
#  'appear',
#  'applicable',
#  'appointment',
#  'appropriate',
#  'approximate',
#  'arbitrary',
#  'arranged',
#  'arrangement',
#  'arrangements',
#  'asreaderspreads',
#  'assert',
#  'attendant',
#  'authors',
#  'autofiltercolorimages',
#  'autofiltergrayimages',
#  'autopositionepsfiles',
#  'autorotatepages',
#  'available',
#  'averaging',
#  'barefooted',
#  'beginning',
#  'bilistically',
#  'binding',
#  'bitimages',
#  'blocking',
#  'boston',
#  'boulevard',
#  'boundary',
#  'bounds',
#  'broaden',
#  'burlington',
#  'business',
#  'calcmykprofile',
#  'calculate',
#  'calculated',
#  'calculating',
#  'calgrayprofile',
#  'calrgbprofile',
#  'cancel',
#  'cancels',
#  'cannot',
#  'cannotembedfontpolicy',
#  'capacity',
#  'categories',
#  'cation',
#  'ccittfaxencode',
#  'center',
#  'certain',
#  'cesses',
#  'cessor',
#  'checkcompliance',
#  'checker',
#  'checks',
#  'children',
#  'claims',
#  'classified',
#  'cleaned',
#  'cleaning',
#  'clearance',
#  'cloudy',
#  'coated',
#  'coeffi',
#  'collision',
#  'collisions',
#  'colorconversionstrategy',
#  'colorimageautofilterstrategy',
#  'colorimagedepth',
#  'colorimagedownsamplethreshold',
#  'colorimagedownsampletype',
#  'colorimagefilter',
#  'colorimagemindownsampledepth',
#  'colorimageminresolution',
#  'colorimageminresolutionpolicy',
#  'colorimageresolution',
#  'colorsettingsfile',
#  'combining',
#  'coming',
#  'commences',
#  'common',
#  'communicates',
#  'compare',
#  'compared',
#  'comparison',
#  'compatibilitylevel',
#  'compete',
#  'completely',
#  'completes',
#  'compounds',
#  'compressobjects',
#  'compresspages',
#  'computationally',
#  'computing',
#  'concave',
#  'concerned',
#  'condemned',
#  'connect',
#  'considering',
#  'consistent',
#  'constantly',
#  'consti',
#  'constraint',
#  'construct',
#  'contact',
#  'contain',
#  'contents',
#  'continuation',
#  'continue',
#  'contradicts',
#  'contributions',
#  'contributors',
#  'converge',
#  'convertcolors',
#  'convertimagestoindexed',
#  'converttocmyk',
#  'corporate',
#  'counter',
#  'counterclockwise',
#  'counterexample',
#  'coupons',
#  'create',
#  'created',
#  'createjdffile',
#  'createjobticket',
#  'creativesuite',
#  'cropcolorimages',
#  'cropgrayimages',
#  'cropimagestoframes',
#  'cropmonoimages',
#  'cubing',
#  'current',
#  'cutting',
#  'cycles',
#  'damage',
#  'datavaluesaredistinct',
#  'deaths',
#  'decrease',
#  'default',
#  'defaultrenderingintent',
#  'defining',
#  'delayed',
#  'deleted',
#  'denomination',
#  'denotes',
#  'denoting',
#  'densities',
#  'depart',
#  'departing',
#  'depending',
#  'derive',
#  'described',
#  'description',
#  'destinationprofilename',
#  'destinationprofileselector',
#  'details',
#  'detectblends',
#  'detectcurves',
#  'developed',
#  'diacritech',
#  'differen',
#  'differentiation',
#  'disciplines',
#  'discounted',
#  'discov',
#  'discrete',
#  'disjointness',
#  'dispatched',
#  'distance',
#  'ditioned',
#  'divide',
#  'doctor',
#  'dothumbnails',
#  'downsample',
#  'downsamplecolorimages',
#  'downsamplegrayimages',
#  'downsamplemonoimages',
#  'driver',
#  'driving',
#  'dscreportinglevel',
#  'earlier',
#  'earliest',
#  'ecfcgc',
#  'edition',
#  'editors',
#  'electronic',
#  'elsevierdirect',
#  'elsewhere',
#  'embedallfonts',
#  'embedjoboptions',
#  'embedopentype',
#  'emitdscwarnings',
#  'employ',
#  'employed',
#  'employee',
#  'employees',
#  'employer',
#  'enables',
#  'encodecolorimages',
#  'encodegrayimages',
#  'encodemonoimages',
#  'encodepages',
#  'endpage',
#  'entiate',
#  'entrance',
#  'erlang',
#  'errorcontrol',
#  'erwise',
#  'essence',
#  'essential',
#  'established',
#  'estimated',
#  'evaluated',
#  'evaluating',
#  'examples',
#  'exceeding',
#  'exceeds',
#  'except',
#  'excluding',
#  'exists',
#  'exneyn',
#  'expect',
#  'experiments',
#  'explanation',
#  'exponentially',
#  'extent',
#  'faster',
#  'finding',
#  'finished',
#  'fixing',
#  'flattenerignorespreadoverrides',
#  'flattenerpreset',
#  'followed',
#  'formal',
#  'formally',
#  'formelements',
#  'former',
#  'formulas',
#  'fortune',
#  'fourth',
#  'francisco',
#  'freedom',
#  'freshman',
#  'fullest',
#  'future',
#  'gebruik',
#  'gemaakte',
#  'generatestructure',
#  'geomet',
#  'geopend',
#  'geoptimaliseerd',
#  'getting',
#  'grayimageautofilterstrategy',
#  'grayimagedepth',
#  'grayimagedownsamplethreshold',
#  'grayimagedownsampletype',
#  'grayimagefilter',
#  'grayimagemindownsampledepth',
#  'grayimageminresolution',
#  'grayimageminresolutionpolicy',
#  'grayimageresolution',
#  'handed',
#  'happens',
#  'headed',
#  'headoccurs',
#  'heidelberg',
#  'hospital',
#  'hotels',
#  'hwresolution',
#  'hybrids',
#  'hypothe',
#  'identi',
#  'identical',
#  'imagememory',
#  'imately',
#  'imating',
#  'imation',
#  'impossible',
#  'improve',
#  'includebookmarks',
#  'includeguidesgrids',
#  'includehyperlinks',
#  'includeinteractive',
#  'includelayers',
#  'includenonprinting',
#  'includeprofiles',
#  'includes',
#  'includeslug',
#  'incorrect',
#  'increase',
#  'increment',
#  'indesign',
#  'indicate',
#  'inductive',
#  'inspection',
#  'instances',
#  'instellingen',
#  'instructions',
#  'instructor',
#  'integrating',
#  'interested',
#  'introduce',
#  'introduction',
#  'invalid',
#  'inverse',
#  'involve',
#  'irrelevant',
#  'iterating',
#  'iterations',
#  'joined',
#  'justify',
#  'kidlington',
#  'knight',
#  'kolmogorov',
#  'kunnen',
#  'kwaliteit',
#  'langford',
#  'laping',
#  'lapping',
#  'launched',
#  'launching',
#  'lawyers',
#  'leavecolorunchanged',
#  'leaveuntagged',
#  'legacy',
#  'lengths',
#  'letter',
#  'lettingrdenote',
#  'licensing',
#  'little',
#  'lockdistillerparams',
#  'london',
#  'longer',
#  'losses',
#  'lowest',
#  'lowing',
#  'makeup',
#  'making',
#  'manual',
#  'markovian',
#  'matching',
#  'material',
#  'mathematically',
#  'mating',
#  'matings',
#  'maxsubsetpct',
#  'mechanical',
#  'medical',
#  'mediumresolution',
#  'metric',
#  'mindful',
#  'minimizes',
#  'minixi',
#  'minutes',
#  'modeled',
#  'models',
#  'modulo',
#  'monoimagedepth',
#  'monoimagedict',
#  'monoimagedownsamplethreshold',
#  'monoimagedownsampletype',
#  'monoimagefilter',
#  'monoimageminresolution',
#  'monoimageminresolutionpolicy',
#  'monoimageresolution',
#  'months',
#  'multimediahandling',
#  'multiple',
#  'multiplying',
#  'mutations',
#  'namely',
#  'necessary',
#  'negligence',
#  'network',
#  'neverembed',
#  'nonempty',
#  'nonhomogeneous',
#  'nonnegative',
#  'nonoverlapping',
#  'nonred',
#  'notational',
#  'notice',
#  'notices',
#  'numerator',
#  'objects',
#  'observe',
#  'observing',
#  'obtains',
#  'occurring',
#  'office',
#  'official',
#  'oldest',
#  'omitplacedbitmaps',
#  'omitplacedeps',
#  'omitplacedpdf',
#  'opened',
#  'optimal',
#  'optimize',
#  'optimum',
#  'orbiting',
#  'orbits',
#  'ordered',
#  'ordinary',
#  'organizations',
#  'originating',
#  'othernamespaces',
#  'others',
#  'overlap',
#  'pagesize',
#  'pairings',
#  'paradox',
#  'parallel',
#  'parsedsccomments',
#  'parsedsccommentsfordocinfo',
#  'parseiccprofilesincomments',
#  'particular',
#  'passing',
#  'passthroughjpegimages',
#  'pdfxbleedboxtotrimboxoffset',
#  'pdfxcompliantpdfonly',
#  'pdfxnotrimboxerror',
#  'pdfxoutputcondition',
#  'pdfxoutputconditionidentifier',
#  'pdfxoutputintentprofile',
#  'pdfxoutputintentprofileselector',
#  'pdfxregistryname',
#  'pdfxsetbleedboxtomediabox',
#  'pdfxtrapped',
#  'pdfxtrimboxtomediaboxoffset',
#  'pendence',
#  'percent',
#  'performance',
#  'periods',
#  'persons',
#  'perusing',
#  'phones',
#  'photocopying',
#  'picked',
#  'pictures',
#  'pijpjk',
#  'pikpkj',
#  'pjkpkj',
#  'places',
#  'playing',
#  'poissons',
#  'policies',
#  'policyholder',
#  'ponent',
#  'population',
#  'positions',
#  'possess',
#  'practice',
#  'practitioners',
#  'preferable',
#  'preserve',
#  'preservecopypage',
#  'preservedicmykvalues',
#  'preserveediting',
#  'preserveepsinfo',
#  'preserveflatness',
#  'preservehalftoneinfo',
#  'preserveopicomments',
#  'preserveoverprintsettings',
#  'presetselector',
#  'printing',
#  'priority',
#  'probabilistically',
#  'problems',
#  'processors',
#  'protected',
#  'proved',
#  'provided',
#  'publication',
#  'publications',
#  'putting',
#  'quantities',
#  'quently',
#  'questioned',
#  'questioning',
#  'raining',
#  'reached',
#  'reasonable',
#  'recall',
#  'receive',
#  'received',
#  'recognize',
#  'recording',
#  'recovering',
#  'recursively',
#  'reduces',
#  'regarding',
#  'regular',
#  'rejection',
#  'related',
#  'remain',
#  'remark',
#  'removal',
#  'reneval',
#  'repair',
#  'repairmen',
#  'repeating',
#  'replace',
#  'represents',
#  'reproduced',
#  'request',
#  'require',
#  'requiring',
#  'researchers',
#  'reselected',
#  'reserved',
#  'resigning',
#  'resigns',
#  'respec',
#  'responsibility',
#  'restarts',
#  'restate',
#  'resultant',
#  'resulting',
#  'resumes',
#  'retrieval',
#  'returning',
#  'reveals',
#  'rewritten',
#  'rights',
#  'rigorous',
#  'rjpjipjk',
#  'rjpjkpji',
#  'sampler',
#  'saying',
#  'scheduled',
#  'selections',
#  'selling',
#  'sequentially',
#  'serving',
#  'setdistillerparams',
#  'setpagedevice',
#  'settings',
#  'sheldon',
#  'shelves',
#  'sibling',
#  'signify',
#  'simply',
#  'simulateoverprint',
#  'singapore',
#  'sition',
#  'sitions',
#  'skiing',
#  'solves',
#  'something',
#  'southern',
#  'spades',
#  'specific',
#  'squares',
#  'srgbprofile',
#  'stability',
#  'stable',
#  'stands',
#  'startpage',
#  'statement',
#  'statistics',
#  'staying',
#  'stirling',
#  'stochas',
#  'stopped',
#  'storage',
#  'straightforward',
#  'stream',
#  'street',
#  'strictly',
#  'structure',
#  'students',
#  'subpath',
#  'subset',
#  'subsetfonts',
#  'substitute',
#  'subtracting',
#  'suggests',
#  'suited',
#  'summation',
#  'supposed',
#  'supposes',
#  'supposing',
#  'surement',
#  'switches',
#  'switching',
#  'sydney',
#  'systemrate',
#  'terminology',
#  'themomentthat',
#  'thenth',
#  'theory',
#  'therewardearnedbetweenrenewalepochs',
#  'throughout',
#  'tially',
#  'tiating',
#  'ticket',
#  'tijpijpi',
#  'tively',
#  'tomorrow',
#  'tosses',
#  'totals',
#  'transfer',
#  'transferfunctioninfo',
#  'transi',
#  'transmitted',
#  'treatment',
#  'truncation',
#  'typeset',
#  'typical',
#  'ucrandbginfo',
#  'umbrellas',
#  'unaffected',
#  'uncounted',
#  'underlying',
#  'understanding',
#  'uniformization',
#  'uniformized',
#  'uninfected',
#  'university',
#  'unreported',
#  'untaggedcmykhandling',
#  'untaggedrgbhandling',
#  'usedocumentbleed',
#  'usedocumentprofile',
#  'useobjectsettings',
#  'useprologue',
#  'utilize',
#  'variances',
#  'verified',
#  'verifies',
#  'version',
#  'vicing',
#  'viewing',
#  'visiting',
#  'warnandcontinue',
#  'website',
#  'weights',
#  'whenindepen',
#  'willing',
#  'winnings',
#  'withdrawal',
#  'worden',
#  'writes',
#  'yearly',
#  'yiapij'}
